# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # New section

# %%
Iris=pd.read_csv('/content/Iris.csv')
Iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
Iris[Iris['SepalWidthCm']>4]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 15  16            5.7           4.4            1.5           0.4  Iris-setosa
# 32  33            5.2           4.1            1.5           0.1  Iris-setosa
# 33  34            5.5           4.2            1.4           0.2  Iris-setosa

# %%
Iris[Iris['PetalWidthCm']>1]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 50    51            7.0           3.2            4.7           1.4
# 51    52            6.4           3.2            4.5           1.5
# 52    53            6.9           3.1            4.9           1.5
# 53    54            5.5           2.3            4.0           1.3
# 54    55            6.5           2.8            4.6           1.5
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#              Species
# 50   Iris-versicolor
# 51   Iris-versicolor
# 52   Iris-versicolor
# 53   Iris-versicolor
# 54   Iris-versicolor
# ..               ...
# ...

# %%
Iris[Iris['PetalLengthCm']>5]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 83    84            6.0           2.7            5.1           1.6
# 100  101            6.3           3.3            6.0           2.5
# 101  102            5.8           2.7            5.1           1.9
# 102  103            7.1           3.0            5.9           2.1
# 103  104            6.3           2.9            5.6           1.8
# 104  105            6.5           3.0            5.8           2.2
# 105  106            7.6           3.0            6.6           2.1
# 107  108            7.3           2.9            6.3           1.8
# 108  109            6.7           2.5            5.8           1.8
# 109  110            7.2           3.6            6.1           2.5
# 110  111            6.5           3.2            5.1           2.0
# 111  112            6.4           2.7            5.3           1.9
# 112  113            6.8           3.0            5.5           2.1
# ...

# %%
Iris[Iris['SepalLengthCm']>6]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 50    51            7.0           3.2            4.7           1.4
# 51    52            6.4           3.2            4.5           1.5
# 52    53            6.9           3.1            4.9           1.5
# 54    55            6.5           2.8            4.6           1.5
# 56    57            6.3           3.3            4.7           1.6
# ..   ...            ...           ...            ...           ...
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
#
#              Species
# 50   Iris-versicolor
# 51   Iris-versicolor
# 52   Iris-versicolor
# 54   Iris-versicolor
# 56   Iris-versicolor
# ..               ...
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
sns.scatterplot(x='SepalLengthCm',y='PetalLengthCm',data=Iris,hue='Species')
plt.show()

# %%
Iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
y = Iris['SepalLengthCm']
x = Iris['SepalWidthCm']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,)

# %%
x_train.head()
# Out:
# 19    3.8
# 66    3.0
# 87    2.3
# 99    2.8
# 47    3.2
# Name: SepalWidthCm, dtype: float64

# %%
x_test.head()
# Out:
# 112    3.0
# 11     3.4
# 114    2.8
# 85     3.4
# 121    2.8
# Name: SepalWidthCm, dtype: float64

# %%
y_train.head()
# Out:
# 19    5.1
# 66    5.6
# 87    6.3
# 99    5.7
# 47    4.6
# Name: SepalLengthCm, dtype: float64

# %%
y_test.head()
# Out:
# 112    6.8
# 11     4.8
# 114    5.8
# 85     6.0
# 121    5.6
# Name: SepalLengthCm, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train.to_frame(),y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test.to_frame())

# %%
y_test.head()
# Out:
# 112    6.8
# 11     4.8
# 114    5.8
# 85     6.0
# 121    5.6
# Name: SepalLengthCm, dtype: float64

# %%
y_pred[0:5]
# Out:
# array([5.84013504, 5.64668062, 5.93686225, 5.64668062, 5.93686225])

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.8088396997757775

# %% [markdown]
# Now we are going to apply Multiple linear Regression

# %%
y=Iris[['SepalLengthCm']]
x = Iris[['SepalWidthCm' , 'PetalLengthCm' , 'PetalWidthCm']]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)

# %%
lr2 = LinearRegression()

# %%
Ir2=lr2.fit(x_train,y_train)

# %%
y_predlr2=Ir2.predict(x_test)

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.5715548611669953

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# -0.09085635613870457

# %%
from sklearn.metrics import r2_score
print('r2 score for the multiple linear regression model is', r2_score(y_test, y_predlr2))
# Out:
# r2 score for the multiple linear regression model is 0.8125469484996244
